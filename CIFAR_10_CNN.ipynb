# %%
import torch
import torchvision
import torchvision.transforms as transforms
import PIL

train_transform = transforms.Compose(
    [transforms.RandomHorizontalFlip(p=0.5),
     transforms.RandomAffine(degrees=(-5, 5), translate=(0.1, 0.1), scale=(0.9, 1.1), resample=PIL.Image.BILINEAR),
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

test_transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=train_transform)
train_set, val_set = torch.utils.data.random_split(dataset, [40000, 10000])

train_loader = torch.utils.data.DataLoader(train_set, batch_size=128, shuffle=True, num_workers=8)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=128, shuffle=False, num_workers=8)

test_set = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_set, batch_size=128, shuffle=False, num_workers=8)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

#classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:1428: UserWarning: The parameter 'resample' is deprecated since 0.12 and will be removed in 0.14. Please use 'interpolation' instead.
#   "The parameter 'resample' is deprecated since 0.12 and will be removed in 0.14. "
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified

# %% [markdown]
# #View an Image in More Detail
# Here, we look at the normalized red, green, and blue (RGB) color channels as three separate, grayscale intensity images.

# %%
import matplotlib.pyplot as plt
import numpy as np

# visualize training image for each class
sample_images = [dataset.data[np.asarray(dataset.targets) == label][0] for label in range(10)]
# show images
fig, axes = plt.subplots(2, 5, figsize=(12, 6))
i = 0
for row in axes:
  for axis in row:
    axis.set_xticks([])
    axis.set_yticks([])
    axis.set_xlabel(classes[i], fontsize=15)
    axis.imshow(sample_images[i])
    i += 1

# %% [markdown]
# #Define CNN architecture

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    self.conv1 = nn.Conv2d(3, 128, 5, padding=2)
    self.conv2 = nn.Conv2d(128, 128, 5, padding=2)
    self.conv3 = nn.Conv2d(128, 256, 3, padding=1)
    self.conv4 = nn.Conv2d(256, 256, 3, padding=1)
    self.pool = nn.MaxPool2d(2, 2)
    self.bn_conv1 = nn.BatchNorm2d(128)
    self.bn_conv2 = nn.BatchNorm2d(128)
    self.bn_conv3 = nn.BatchNorm2d(256)
    self.bn_conv4 = nn.BatchNorm2d(256)
    self.bn_dense1 = nn.BatchNorm1d(1024)
    self.bn_dense2 = nn.BatchNorm1d(512)
    self.dropout_conv = nn.Dropout2d(p=0.25)
    self.dropout = nn.Dropout(p=0.5)
    self.fc1 = nn.Linear(256 * 8 * 8, 1024)
    self.fc2 = nn.Linear(1024, 512)
    self.fc3 = nn.Linear(512, 10)

  def conv_layers(self, x):
    out = F.relu(self.bn_conv1(self.conv1(x)))
    out = F.relu(self.bn_conv2(self.conv2(out)))
    out = self.pool(out)
    out = self.dropout_conv(out)
    out = F.relu(self.bn_conv3(self.conv3(out)))
    out = F.relu(self.bn_conv4(self.conv4(out)))
    out = self.pool(out)
    out = self.dropout_conv(out)
    return out

  def dense_layers(self, x):
    out = F.relu(self.bn_dense1(self.fc1(x)))
    out = self.dropout(out)
    out = F.relu(self.bn_dense2(self.fc2(out)))
    out = self.dropout(out)
    out = self.fc3(out)
    return out

  def forward(self, x):
    out = self.conv_layers(x)
    out = out.view(-1, 256 * 8 * 8)
    out = self.dense_layers(out)
    return out

net = Net()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print('Device:', device)
net.to(device)

num_params = sum(p.numel() for p in net.parameters() if p.requires_grad)
print("Number of trainable parameters:", num_params)
# Out:
# Device: cuda:0
# Number of trainable parameters: 18617482

# %% [markdown]
# #Train the Netwrok

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.01, betas=(0.9, 0.999), eps=1e-08, weight_decay=0, amsgrad=False)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=10, verbose=True, min_lr=0)

loss_hist, acc_hist = [], []
loss_hist_val, acc_hist_val = [], []

for epoch in range(140):
  running_loss = 0.0
  correct = 0
  for data in train_loader:
    batch, labels = data
    batch, labels = batch.to(device), labels.to(device)

    optimizer.zero_grad()
    outputs = net(batch)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()

    # compute training statistics
    _, predicted = torch.max(outputs, 1)
    correct += (predicted == labels).sum().item()
    running_loss += loss.item()

  avg_loss = running_loss / len(train_set)
  avg_acc = correct / len(train_set)
  loss_hist.append(avg_loss)
  acc_hist.append(avg_acc)

  # validation statistics
  net.eval()
  with torch.no_grad():
    loss_val = 0.0
    correct_val = 0
    for data in val_loader:
      batch, labels = data
      batch, labels = batch.to(device), labels.to(device)
      outputs = net(batch)
      loss = criterion(outputs, labels)
      _, predicted = torch.max(outputs, 1)
      correct_val += (predicted == labels).sum().item()
      loss_val += loss.item()
    avg_loss_val = loss_val / len(val_set)
    avg_acc_val = correct_val / len(val_set)
    loss_hist_val.append(avg_loss_val)
    acc_hist_val.append(avg_acc_val)
  net.train()

  scheduler.step(avg_loss_val)
  print('[epoch %d] loss: %.5f accuracy: %.4f val loss: %.5f val accuracy: %.4f' % (epoch + 1, avg_loss, avg_acc, avg_loss_val, avg_acc_val*100))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# [epoch 1] loss: 0.01398 accuracy: 0.3537 val loss: 0.01172 val accuracy: 0.4525
# [epoch 2] loss: 0.01159 accuracy: 0.4612 val loss: 0.01016 val accuracy: 0.5347
# [epoch 3] loss: 0.01003 accuracy: 0.5415 val loss: 0.00917 val accuracy: 0.5822
# [epoch 4] loss: 0.00879 accuracy: 0.6021 val loss: 0.00734 val accuracy: 0.6692
# [epoch 5] loss: 0.00788 accuracy: 0.6455 val loss: 0.00676 val accuracy: 0.6960
# [epoch 6] loss: 0.00733 accuracy: 0.6747 val loss: 0.00637 val accuracy: 0.7133
# [epoch 7] loss: 0.00689 accuracy: 0.6936 val loss: 0.00585 val accuracy: 0.7414
# [epoch 8] loss: 0.00652 accuracy: 0.7134 val loss: 0.00543 val accuracy: 0.7553
# [epoch 9] loss: 0.00621 accuracy: 0.7262 val loss: 0.00538 val accuracy: 0.7621
# [epoch 10] loss: 0.00598 accuracy: 0.7362 val loss: 0.00507 val accuracy: 0.7742
# [epoch 11] loss: 0.00572 accuracy: 0.7500 val loss: 0.00505 val accuracy: 0.7786
# [epoch 12] loss: 0.00556 accuracy: 0.7551 val loss: 0.00452 val accuracy: 0.7996
# [epoch 13] loss: 0.00531 accuracy: 0.7667 val loss: 0.00468 val accuracy: 0.7967
# [epoch 14] loss: 0.00515 accuracy: 0.7772 val loss: 0.00445 val accuracy: 0.8048
# [epoch 15] loss: 0.00502 accuracy: 0.7812 val loss: 0.00418 val accuracy: 0.8155
# [epoch 16] loss: 0.00485 accuracy: 0.7873 val loss: 0.00413 val accuracy: 0.8175
# [epoch 17] loss: 0.00472 accuracy: 0.7923 val loss: 0.00416 val accuracy: 0.8186
# [epoch 18] loss: 0.00461 accuracy: 0.7978 val loss: 0.00406 val accuracy: 0.8253
# [epoch 19] loss: 0.00453 accuracy: 0.8038 val loss: 0.00388 val accuracy: 0.8317
# [epoch 20] loss: 0.00438 accuracy: 0.8104 val loss: 0.00384 val accuracy: 0.8336
# [epoch 21] loss: 0.00433 accuracy: 0.8115 val loss: 0.00380 val accuracy: 0.8338
# [epoch 22] loss: 0.00423 accuracy: 0.8163 val loss: 0.00364 val accuracy: 0.8406
# [epoch 23] loss: 0.00408 accuracy: 0.8223 val loss: 0.00372 val accuracy: 0.8387
# [epoch 24] loss: 0.00401 accuracy: 0.8265 val loss: 0.00359 val accuracy: 0.8453
# [epoch 25] loss: 0.00397 accuracy: 0.8269 val loss: 0.00360 val accuracy: 0.8458
# [epoch 26] loss: 0.00385 accuracy: 0.8327 val loss: 0.00354 val accuracy: 0.8465
# [epoch 27] loss: 0.00376 accuracy: 0.8354 val loss: 0.00360 val accuracy: 0.8449
# [epoch 28] loss: 0.00370 accuracy: 0.8386 val loss: 0.00336 val accuracy: 0.8558
# [epoch 29] loss: 0.00365 accuracy: 0.8409 val loss: 0.00350 val accuracy: 0.8503
# [epoch 30] loss: 0.00358 accuracy: 0.8428 val loss: 0.00332 val accuracy: 0.8571
# [epoch 31] loss: 0.00350 accuracy: 0.8491 val loss: 0.00337 val accuracy: 0.8572
# [epoch 32] loss: 0.00345 accuracy: 0.8507 val loss: 0.00332 val accuracy: 0.8592
# [epoch 33] loss: 0.00342 accuracy: 0.8532 val loss: 0.00334 val accuracy: 0.8596
# [epoch 34] loss: 0.00335 accuracy: 0.8562 val loss: 0.00349 val accuracy: 0.8487
# [epoch 35] loss: 0.00336 accuracy: 0.8528 val loss: 0.00342 val accuracy: 0.8554
# [epoch 36] loss: 0.00328 accuracy: 0.8566 val loss: 0.00318 val accuracy: 0.8660
# [epoch 37] loss: 0.00321 accuracy: 0.8593 val loss: 0.00307 val accuracy: 0.8684
# [epoch 38] loss: 0.00315 accuracy: 0.8628 val loss: 0.00308 val accuracy: 0.8672
# [epoch 39] loss: 0.00306 accuracy: 0.8670 val loss: 0.00314 val accuracy: 0.8683
# [epoch 40] loss: 0.00306 accuracy: 0.8675 val loss: 0.00309 val accuracy: 0.8675
# [epoch 41] loss: 0.00302 accuracy: 0.8692 val loss: 0.00306 val accuracy: 0.8672
# [epoch 42] loss: 0.00298 accuracy: 0.8697 val loss: 0.00307 val accuracy: 0.8724
# [epoch 43] loss: 0.00295 accuracy: 0.8720 val loss: 0.00312 val accuracy: 0.8689
# [epoch 44] loss: 0.00291 accuracy: 0.8732 val loss: 0.00312 val accuracy: 0.8699
# [epoch 45] loss: 0.00286 accuracy: 0.8755 val loss: 0.00309 val accuracy: 0.8679
# [epoch 46] loss: 0.00284 accuracy: 0.8790 val loss: 0.00311 val accuracy: 0.8707
# [epoch 47] loss: 0.00284 accuracy: 0.8788 val loss: 0.00314 val accuracy: 0.8722
# [epoch 48] loss: 0.00280 accuracy: 0.8786 val loss: 0.00311 val accuracy: 0.8668
# [epoch 49] loss: 0.00274 accuracy: 0.8817 val loss: 0.00294 val accuracy: 0.8773
# [epoch 50] loss: 0.00266 accuracy: 0.8827 val loss: 0.00302 val accuracy: 0.8747
# [epoch 51] loss: 0.00271 accuracy: 0.8809 val loss: 0.00306 val accuracy: 0.8707
# [epoch 52] loss: 0.00261 accuracy: 0.8872 val loss: 0.00303 val accuracy: 0.8749
# [epoch 53] loss: 0.00262 accuracy: 0.8858 val loss: 0.00293 val accuracy: 0.8771
# [epoch 54] loss: 0.00256 accuracy: 0.8891 val loss: 0.00296 val accuracy: 0.8774
# [epoch 55] loss: 0.00257 accuracy: 0.8879 val loss: 0.00312 val accuracy: 0.8715
# [epoch 56] loss: 0.00255 accuracy: 0.8890 val loss: 0.00287 val accuracy: 0.8833
# [epoch 57] loss: 0.00253 accuracy: 0.8890 val loss: 0.00303 val accuracy: 0.8753
# [epoch 58] loss: 0.00244 accuracy: 0.8936 val loss: 0.00293 val accuracy: 0.8806
# [epoch 59] loss: 0.00248 accuracy: 0.8918 val loss: 0.00286 val accuracy: 0.8838
# [epoch 60] loss: 0.00239 accuracy: 0.8964 val loss: 0.00279 val accuracy: 0.8855
# [epoch 61] loss: 0.00235 accuracy: 0.8979 val loss: 0.00279 val accuracy: 0.8890
# [epoch 62] loss: 0.00239 accuracy: 0.8949 val loss: 0.00301 val accuracy: 0.8820
# [epoch 63] loss: 0.00234 accuracy: 0.8974 val loss: 0.00293 val accuracy: 0.8787
# [epoch 64] loss: 0.00238 accuracy: 0.8963 val loss: 0.00284 val accuracy: 0.8851
# [epoch 65] loss: 0.00224 accuracy: 0.9012 val loss: 0.00273 val accuracy: 0.8846
# [epoch 66] loss: 0.00227 accuracy: 0.9002 val loss: 0.00281 val accuracy: 0.8865
# [epoch 67] loss: 0.00223 accuracy: 0.9026 val loss: 0.00293 val accuracy: 0.8843
# [epoch 68] loss: 0.00224 accuracy: 0.9020 val loss: 0.00280 val accuracy: 0.8858
# [epoch 69] loss: 0.00224 accuracy: 0.9023 val loss: 0.00279 val accuracy: 0.8882
# [epoch 70] loss: 0.00218 accuracy: 0.9074 val loss: 0.00285 val accuracy: 0.8807
# [epoch 71] loss: 0.00217 accuracy: 0.9064 val loss: 0.00284 val accuracy: 0.8870
# [epoch 72] loss: 0.00217 accuracy: 0.9050 val loss: 0.00274 val accuracy: 0.8899
# [epoch 73] loss: 0.00218 accuracy: 0.9051 val loss: 0.00278 val accuracy: 0.8905
# [epoch 74] loss: 0.00214 accuracy: 0.9069 val loss: 0.00283 val accuracy: 0.8850
# [epoch 75] loss: 0.00208 accuracy: 0.9083 val loss: 0.00277 val accuracy: 0.8891
# Epoch 00076: reducing learning rate of group 0 to 1.0000e-03.
# [epoch 76] loss: 0.00206 accuracy: 0.9111 val loss: 0.00291 val accuracy: 0.8856
# [epoch 77] loss: 0.00179 accuracy: 0.9224 val loss: 0.00267 val accuracy: 0.8906
# [epoch 78] loss: 0.00167 accuracy: 0.9264 val loss: 0.00259 val accuracy: 0.8968
# [epoch 79] loss: 0.00158 accuracy: 0.9306 val loss: 0.00263 val accuracy: 0.8994
# [epoch 80] loss: 0.00155 accuracy: 0.9307 val loss: 0.00266 val accuracy: 0.8973
# [epoch 81] loss: 0.00148 accuracy: 0.9339 val loss: 0.00260 val accuracy: 0.8987
# [epoch 82] loss: 0.00149 accuracy: 0.9350 val loss: 0.00262 val accuracy: 0.8966
# [epoch 83] loss: 0.00144 accuracy: 0.9360 val loss: 0.00251 val accuracy: 0.9015
# [epoch 84] loss: 0.00144 accuracy: 0.9375 val loss: 0.00255 val accuracy: 0.9000
# [epoch 85] loss: 0.00141 accuracy: 0.9370 val loss: 0.00259 val accuracy: 0.8993
# [epoch 86] loss: 0.00139 accuracy: 0.9391 val loss: 0.00251 val accuracy: 0.9044
# [epoch 87] loss: 0.00141 accuracy: 0.9375 val loss: 0.00255 val accuracy: 0.9002
# [epoch 88] loss: 0.00134 accuracy: 0.9412 val loss: 0.00261 val accuracy: 0.9019
# [epoch 89] loss: 0.00134 accuracy: 0.9414 val loss: 0.00256 val accuracy: 0.9026
# [epoch 90] loss: 0.00133 accuracy: 0.9421 val loss: 0.00256 val accuracy: 0.9026
# [epoch 91] loss: 0.00130 accuracy: 0.9426 val loss: 0.00268 val accuracy: 0.8982
# [epoch 92] loss: 0.00133 accuracy: 0.9405 val loss: 0.00255 val accuracy: 0.9002
# [epoch 93] loss: 0.00130 accuracy: 0.9441 val loss: 0.00257 val accuracy: 0.9010
# Epoch 00094: reducing learning rate of group 0 to 1.0000e-04.
# [epoch 94] loss: 0.00125 accuracy: 0.9452 val loss: 0.00254 val accuracy: 0.9036
# [epoch 95] loss: 0.00128 accuracy: 0.9446 val loss: 0.00262 val accuracy: 0.9029
# [epoch 96] loss: 0.00131 accuracy: 0.9431 val loss: 0.00256 val accuracy: 0.9004
# [epoch 97] loss: 0.00129 accuracy: 0.9433 val loss: 0.00249 val accuracy: 0.9031
# [epoch 98] loss: 0.00127 accuracy: 0.9452 val loss: 0.00247 val accuracy: 0.9034
# [epoch 99] loss: 0.00125 accuracy: 0.9451 val loss: 0.00256 val accuracy: 0.9032
# [epoch 100] loss: 0.00125 accuracy: 0.9446 val loss: 0.00258 val accuracy: 0.8970
# [epoch 101] loss: 0.00126 accuracy: 0.9439 val loss: 0.00252 val accuracy: 0.9040
# [epoch 102] loss: 0.00125 accuracy: 0.9463 val loss: 0.00254 val accuracy: 0.9031
# [epoch 103] loss: 0.00124 accuracy: 0.9452 val loss: 0.00255 val accuracy: 0.9015
# [epoch 104] loss: 0.00123 accuracy: 0.9464 val loss: 0.00262 val accuracy: 0.9039
# [epoch 105] loss: 0.00121 accuracy: 0.9470 val loss: 0.00265 val accuracy: 0.8993
# [epoch 106] loss: 0.00123 accuracy: 0.9455 val loss: 0.00261 val accuracy: 0.9030
# [epoch 107] loss: 0.00119 accuracy: 0.9475 val loss: 0.00263 val accuracy: 0.9030
# [epoch 108] loss: 0.00127 accuracy: 0.9439 val loss: 0.00253 val accuracy: 0.9043
# Epoch 00109: reducing learning rate of group 0 to 1.0000e-05.
# [epoch 109] loss: 0.00122 accuracy: 0.9460 val loss: 0.00260 val accuracy: 0.9037
# [epoch 110] loss: 0.00120 accuracy: 0.9463 val loss: 0.00248 val accuracy: 0.9059
# [epoch 111] loss: 0.00122 accuracy: 0.9457 val loss: 0.00260 val accuracy: 0.9065
# [epoch 112] loss: 0.00121 accuracy: 0.9473 val loss: 0.00257 val accuracy: 0.8993
# [epoch 113] loss: 0.00121 accuracy: 0.9456 val loss: 0.00259 val accuracy: 0.9038
# [epoch 114] loss: 0.00123 accuracy: 0.9462 val loss: 0.00256 val accuracy: 0.9020
# [epoch 115] loss: 0.00124 accuracy: 0.9449 val loss: 0.00259 val accuracy: 0.9005
# [epoch 116] loss: 0.00123 accuracy: 0.9449 val loss: 0.00261 val accuracy: 0.9000
# [epoch 117] loss: 0.00124 accuracy: 0.9467 val loss: 0.00252 val accuracy: 0.9053
# [epoch 118] loss: 0.00121 accuracy: 0.9471 val loss: 0.00251 val accuracy: 0.9032
# [epoch 119] loss: 0.00123 accuracy: 0.9467 val loss: 0.00255 val accuracy: 0.9022
# Epoch 00120: reducing learning rate of group 0 to 1.0000e-06.
# [epoch 120] loss: 0.00120 accuracy: 0.9475 val loss: 0.00258 val accuracy: 0.9009
# [epoch 121] loss: 0.00120 accuracy: 0.9475 val loss: 0.00262 val accuracy: 0.9015
# [epoch 122] loss: 0.00121 accuracy: 0.9473 val loss: 0.00264 val accuracy: 0.9010
# [epoch 123] loss: 0.00123 accuracy: 0.9460 val loss: 0.00257 val accuracy: 0.9030
# [epoch 124] loss: 0.00124 accuracy: 0.9466 val loss: 0.00256 val accuracy: 0.9024
# [epoch 125] loss: 0.00124 accuracy: 0.9447 val loss: 0.00258 val accuracy: 0.9032
# [epoch 126] loss: 0.00121 accuracy: 0.9447 val loss: 0.00256 val accuracy: 0.9019
# [epoch 127] loss: 0.00122 accuracy: 0.9456 val loss: 0.00251 val accuracy: 0.9070
# [epoch 128] loss: 0.00123 accuracy: 0.9465 val loss: 0.00259 val accuracy: 0.9013
# [epoch 129] loss: 0.00120 accuracy: 0.9474 val loss: 0.00250 val accuracy: 0.9054
# [epoch 130] loss: 0.00122 accuracy: 0.9469 val loss: 0.00258 val accuracy: 0.9014
# Epoch 00131: reducing learning rate of group 0 to 1.0000e-07.
# [epoch 131] loss: 0.00123 accuracy: 0.9472 val loss: 0.00258 val accuracy: 0.9027
# [epoch 132] loss: 0.00120 accuracy: 0.9466 val loss: 0.00259 val accuracy: 0.9001
# [epoch 133] loss: 0.00123 accuracy: 0.9456 val loss: 0.00259 val accuracy: 0.9007
# [epoch 134] loss: 0.00119 accuracy: 0.9472 val loss: 0.00263 val accuracy: 0.9014
# [epoch 135] loss: 0.00125 accuracy: 0.9445 val loss: 0.00260 val accuracy: 0.9034
# [epoch 136] loss: 0.00120 accuracy: 0.9474 val loss: 0.00251 val accuracy: 0.9034
# [epoch 137] loss: 0.00123 accuracy: 0.9472 val loss: 0.00252 val accuracy: 0.9036
# [epoch 138] loss: 0.00124 accuracy: 0.9463 val loss: 0.00254 val accuracy: 0.9065
# [epoch 139] loss: 0.00122 accuracy: 0.9461 val loss: 0.00265 val accuracy: 0.9013
# [epoch 140] loss: 0.00120 accuracy: 0.9474 val loss: 0.00257 val accuracy: 0.9015

# %% [markdown]
# # Visiualzing Training statistics

# %%
import matplotlib.pyplot as plt

legend = ['Train', 'Validation']
plt.plot(loss_hist)
plt.plot(loss_hist_val)
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(legend, loc='upper left')
plt.show()

legend = ['Train', 'Validation']
plt.plot(acc_hist)
plt.plot(acc_hist_val)
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(legend, loc='upper left')
plt.show()

# %% [markdown]
# #Save the trained model

# %%
from google.colab import files

torch.save(net.state_dict(), 'checkpoint.pth')
# download checkpoint file
files.download('checkpoint.pth')

net.load_state_dict(torch.load('checkpoint.pth'))
# Out:
# <All keys matched successfully>

# %% [markdown]
# #Test the Trained Network

# %%
pred_vec = []
correct = 0
net.eval()
with torch.no_grad():
    for data in test_loader:
        batch, labels = data
        batch, labels = batch.to(device), labels.to(device)
        outputs = net(batch)
        _, predicted = torch.max(outputs, 1)
        correct += (predicted == labels).sum().item()
        pred_vec.append(predicted)
    pred_vec = torch.cat(pred_vec)

print('Accuracy on the 10000 test images: %.2f %%' % (100 * correct / len(test_set)))
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:560: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Accuracy on the 10000 test images: 90.36 %
